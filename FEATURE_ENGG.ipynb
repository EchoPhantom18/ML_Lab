# %% [markdown]
# Feature Scaling

# %%
import sklearn

# %%
#min max scaling
from sklearn.preprocessing import MinMaxScaler

# %%
Scaler=MinMaxScaler()
scaler.fit(X_train) # fit the scaker to the training data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 Scaler=MinMaxScaler()
# ----> 2 scaler.fit(X_train)
#
# NameError: name 'scaler' is not defined

# %%
x_train_scaled = scaler.transform(X_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 x_train_scaled = scaler.transform(X_train)
#
# NameError: name 'scaler' is not defined

# %%
def mean_scaling(X):
    x_mean = X.mean()
    x_max = X.max()
    x_min = X.min()
    return (X-x_mean)/(X_max - x_min)

# %%
from sklearn.preprocessing imprt MaxAbsScaler
max_abs_scaler = Max_absScaler()
