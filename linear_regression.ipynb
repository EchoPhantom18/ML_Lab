# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df= pd.read_csv('price.csv ')
df
# Out:
#    area  price
# 0     1      3
# 1     2      5
# 2     3      7
# 3     4      8
# 4     5     10

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
plt.scatter(X, y, color='blue', label='Actual Data')

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.scatter(df['area'], df['price'])
plt.xlabel('Area')
plt.ylabel('Price')

plt.plot(X, model.predict(X), color='red', label='Regression Line')

# %%
import seaborn as sns
sns.lineplot(x='area', y='price', data=df)
plt.xlabel('Area')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
m = model.coef_
c = model.intercept_
print(f"The linear regression equation is: y = {m}x + {c}")
# Out:
# The linear regression equation is: y = [1.7]x + 1.4999999999999991

# %%
# Example: predict price for area = 100
X100 = [[100]]
y_pred_100 = model.predict(X100)
print(f"Predicted price for area 100: {y_pred_100[0]}")
# Out:
# Predicted price for area 100: 171.50000000000003
# c:\Users\Tanmay varma\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
